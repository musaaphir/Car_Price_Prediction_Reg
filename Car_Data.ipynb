# %% [markdown]
# ## About Project

# %% [markdown]
# ## Old Car Price Prediction

# %% [markdown]
# ## Objective

# %% [markdown]
# # •	The objective of the project is to build a smart old car price prediction application using some Machine Learning techniques. Where in for a new data will be able to predict the proper price of the car.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(10,6)
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("car-data.csv")

# %%
df.head()
# Out:
#    year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  2019  25000    Automatic    13904   Diesel  145  49.6         2.0
# 1  2019  26883    Automatic     4562   Diesel  145  49.6         2.0
# 2  2019  20000       Manual     7414   Diesel  145  50.4         2.0
# 3  2019  33492    Automatic     4825   Petrol  145  32.5         2.0
# 4  2019  22900    Semi-Auto     6500   Petrol  150  39.8         1.5

# %%
df.shape
# Out:
# (15157, 8)

# %%
df.isna().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.dtypes
# Out:
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15157 entries, 0 to 15156
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          15157 non-null  int64
#  1   price         15157 non-null  int64
#  2   transmission  15157 non-null  object
#  3   mileage       15157 non-null  int64
#  4   fuelType      15157 non-null  object
#  5   tax           15157 non-null  int64
#  6   mpg           15157 non-null  float64
#  7   engineSize    15157 non-null  float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 947.4+ KB

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  15157.000000  15157.000000   15157.000000  15157.000000  15157.000000
# mean    2017.255789  16838.952365   22092.785644    112.744277     53.753355
# std        2.053059   7755.015206   21148.941635     63.482617     13.642182
# min     2000.000000    899.000000       1.000000      0.000000      0.300000
# 25%     2016.000000  10990.000000    5962.000000     30.000000     46.300000
# 50%     2017.000000  15497.000000   16393.000000    145.000000     53.300000
# 75%     2019.000000  20998.000000   31824.000000    145.000000     60.100000
# max     2020.000000  69994.000000  212000.000000    580.000000    188.300000
#
#          engineSize
# count  15157.000000
# mean       1.600693
# std        0.461695
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        3.200000

# %%
df.columns
# Out:
# Index(['year', 'price', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')

# %%
df["fuelType"].value_counts()
# Out:
# Petrol    8553
# Diesel    6372
# Hybrid     145
# Other       87
# Name: fuelType, dtype: int64

# %%
df["transmission"].value_counts()
# Out:
# Manual       9417
# Semi-Auto    3780
# Automatic    1960
# Name: transmission, dtype: int64

# %%
sns.set()
df.boxplot(figsize=(15,10))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot("mileage",data=df)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df[df.mileage>120000]
df.drop(df[df.mileage>120000].index,inplace=True)

# %%
plt.figure(figsize=(18,6))
sns.boxplot("mileage",data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mileage'>

# %%
sns.set()
df.hist(color='green',figsize=(20,10))
plt.xticks(rotation=90)
plt.show()

# %%
df["year"].value_counts()
# Out:
# 2019    4669
# 2017    2946
# 2016    2643
# 2018    1509
# 2015    1139
# 2020    1046
# 2014     577
# 2013     314
# 2012      79
# 2011      54
# 2010      37
# 2009      30
# 2008      24
# 2007      17
# 2006      14
# 2005       6
# 2001       4
# 2003       2
# 2004       1
# 2002       1
# 2000       1
# Name: year, dtype: int64

# %%
plt.figure(figsize=(16,4))
plt.plot("year","price",data=df)

# %% [markdown]
# ## Which Fule type Car Price is more?

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="fuelType",y="price",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Which Fule type car give more mileage

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="fuelType",y="mileage",data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['year', 'price', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')

# %% [markdown]
# ## Which Transmission Car EngineSize is big

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="engineSize",y="transmission",hue="fuelType",data=df)
plt.show()

# %% [markdown]
# # Ploting Neumarical Column

# %%
plt.figure(figsize=(16,4))

plt.subplot(1,3,1)
sns.scatterplot(x="year",y="price",data=df)
plt.title("Year VS Price")

plt.subplot(1,3,2)
sns.scatterplot(x="mileage",y="price",data=df)
plt.title("mileage VS Price")

plt.subplot(1,3,3)
sns.scatterplot(x="engineSize",y="price",data=df)
plt.title("engineSize VS Price")

plt.show()

# %%
# Checking the price
plt.figure(figsize=(16,4))
sns.distplot(df['price']);
plt.title("Price")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(14,4))
p=sns.distplot(df['price']);
plt.title("Price")
p.set(xscale='log');
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Transform the price

log_price=np.log(df['price'])

#Adding another column

df['log_price']=log_price

#droping the price col
df.drop('price',axis=1,inplace=True)

#Checking
df.head()
# Out:
#    year transmission  mileage fuelType  tax   mpg  engineSize  log_price
# 0  2019    Automatic    13904   Diesel  145  49.6         2.0  10.126631
# 1  2019    Automatic     4562   Diesel  145  49.6         2.0  10.199249
# 2  2019       Manual     7414   Diesel  145  50.4         2.0   9.903488
# 3  2019    Automatic     4825   Petrol  145  32.5         2.0  10.419062
# 4  2019    Semi-Auto     6500   Petrol  150  39.8         1.5  10.038892

# %%
plt.figure(figsize=(16,4))

plt.subplot(1,3,1)
a=sns.scatterplot(x="year",y="log_price",data=df)
plt.title("Year VS log_price")

plt.subplot(1,3,2)
sns.scatterplot(x="mileage",y="log_price",data=df)
plt.title("mileage VS log_price")

plt.subplot(1,3,3)
sns.scatterplot(x="engineSize",y="log_price",data=df)
plt.title("engineSize VS log_price")

plt.show()

# %%
df.corr()
# Out:
#                 year   mileage       tax       mpg  engineSize  log_price
# year        1.000000 -0.765296  0.382712 -0.304947    0.011391   0.709414
# mileage    -0.765296  1.000000 -0.351652  0.342893    0.104016  -0.582649
# tax         0.382712 -0.351652  1.000000 -0.517082    0.291015   0.506373
# mpg        -0.304947  0.342893 -0.517082  1.000000   -0.277496  -0.456323
# engineSize  0.011391  0.104016  0.291015 -0.277496    1.000000   0.548357
# log_price   0.709414 -0.582649  0.506373 -0.456323    0.548357   1.000000

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True,linewidths=1,cmap = 'YlGnBu')
plt.show()

# %%
df.head(2)
# Out:
#    year transmission  mileage fuelType  tax   mpg  engineSize  log_price
# 0  2019    Automatic    13904   Diesel  145  49.6         2.0  10.126631
# 1  2019    Automatic     4562   Diesel  145  49.6         2.0  10.199249

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df["transmission"]=le.fit_transform(df["transmission"])
df["fuelType"]=le.fit_transform(df["fuelType"])

# %%
df.head(2)
# Out:
#    year  transmission  mileage  fuelType  tax   mpg  engineSize  log_price
# 0  2019             0    13904         0  145  49.6         2.0  10.126631
# 1  2019             0     4562         0  145  49.6         2.0  10.199249

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(feature):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = feature.columns
    vif["VIF"] = [variance_inflation_factor(feature.values, i) for i in range(feature.shape[1])]

    return(vif)

# %%
feature = df.iloc[:,:-1]
calc_vif(feature)
# Out:
#       variables         VIF
# 0          year  115.975993
# 1  transmission    4.486122
# 2       mileage    2.788361
# 3      fuelType    5.310020
# 4           tax    6.367623
# 5           mpg   29.395242
# 6    engineSize   32.718743

# %%
x=df.drop("log_price",axis=1,inplace=False)
x.head(2)
# Out:
#    year  transmission  mileage  fuelType  tax   mpg  engineSize
# 0  2019             0    13904         0  145  49.6         2.0
# 1  2019             0     4562         0  145  49.6         2.0

# %%
y=df.log_price
y.head()
# Out:
# 0    10.126631
# 1    10.199249
# 2     9.903488
# 3    10.419062
# 4    10.038892
# Name: log_price, dtype: float64

# %%
import statsmodels.api as sm

# %%
x_s=sm.add_constant(x)
slr=sm.OLS(y,x_s)
slr_model=slr.fit()
slr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              log_price   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                 1.052e+04
# Date:                Thu, 16 Jun 2022   Prob (F-statistic):               0.00
# Time:                        22:20:00   Log-Likelihood:                 3661.1
# No. Observations:               15113   AIC:                            -7306.
# Df Residuals:                   15105   BIC:                            -7245.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Linear Reg

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Variance score: {}'.format(lr.score(x_test, y_test)))
# Out:
# Variance score: 0.8333521145290819

# %%
print("Intercept :",lr.intercept_)
# Out:
# Intercept : -224.25915785471247

# %%
print('Coefficients: ', lr.coef_)
# Out:
# Coefficients:  [ 1.15499454e-01  2.64236980e-02 -4.78003884e-06  2.23680748e-02
#   3.99684680e-04 -8.85003952e-04  5.84815420e-01]

# %%
y_hat_lr=lr.predict(x_test)
y_hat_lr
# Out:
# array([ 9.51999769,  9.03562051,  9.62420468, ...,  9.86969993,
#        10.0269875 ,  9.83616565])

# %%
plt.figure(figsize=(16,4))
plt.plot(y_test,color="blue")
plt.plot(y_hat_lr,color="green")
plt.show()

# %%
## plotting residual errors in training data
plt.figure(figsize=(15,6))
plt.scatter(lr.predict(x_train), lr.predict(x_train) - y_train, color = "green", s = 10, label = 'Train data')
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2)
plt.title("Residual errors Train Data")
plt.show()

# %%
## plotting residual errors in test data
plt.figure(figsize=(15,6))
plt.scatter(lr.predict(x_test), lr.predict(x_test) - y_test,color = "blue", s = 10, label = 'Test data')
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2)
plt.title("Residual errors test Data")
plt.show()

# %%
## Combining both the Graph
plt.figure(figsize=(15,6))
plt.scatter(lr.predict(x_train), lr.predict(x_train) - y_train, color = "green", s = 10, label = 'Train data')
plt.scatter(lr.predict(x_test), lr.predict(x_test) - y_test,color = "blue", s = 10, label = 'Test data')
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2)
plt.title("Residual errors")
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf=rf.predict(x_test)
y_pred_rf
# Out:
# array([ 9.69750208,  8.9022172 ,  9.66190137, ...,  9.75786042,
#        10.0162952 ,  9.97496216])

# %%
rf.score(x_test,y_test)
# Out:
# 0.9435572893538537

# %%
plt.figure(figsize=(16,4))
plt.plot(y_test,color="blue")
plt.plot(y_pred_rf,color="green")
plt.show()

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb
xg_reg = xgb.XGBRegressor()
from sklearn.metrics import mean_squared_error as MSE

# %%
xg_reg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_pred_xgb = xg_reg.predict(x_test)

# %%
y_pred_xgb
# Out:
# array([ 9.780891,  8.831414,  9.652751, ...,  9.759341, 10.029777,
#         9.923526], dtype=float32)

# %%
xg_reg.score(x_test,y_test)
# Out:
# 0.9477888439503499

# %%
plt.figure(figsize=(16,4))
plt.plot(y_test,color="blue")
plt.plot(y_pred_xgb,color="green")
plt.show()

# %%
# RMSE Computation
rmse = np.sqrt(MSE(y_test, y_pred_xgb))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  0.104753

# %%
plt.figure(figsize=(20,10))
plt.plot(y_hat_lr,color="green")
plt.plot(y_pred_xgb,color="blue")
plt.plot(y_pred_rf,color="red")
plt.show()

# %%
import pickle
filename = 'finalized_model.sav'

# %%
pickle.dump(lr, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.8333521145290819

# %%
loaded_model.predict(x_test)
# Out:
# array([ 9.51999769,  9.03562051,  9.62420468, ...,  9.86969993,
#        10.0269875 ,  9.83616565])
